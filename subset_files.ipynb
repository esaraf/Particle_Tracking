# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
# %qtconsole

# %%
# years downloaded
yr_bgn = 2015
yr_end = 2015

# days downloaded
day_bgn = 1
day_end = 365

# directory path of netcdf files
# dir_in = '/Users/esaraf/Desktop/NOAA/GlobCurrent/GlobCurrent.geostrophic.data/geostrophic/'
dir_in = '/Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic'

# Subset data to get CCS
lon_bgn = -130
lon_end = -110
lat_bgn = 20
lat_end = 50

# subset and save these variable
var_wnt = ['eastward_geostrophic_current_velocity',
           'northward_geostrophic_current_velocity']

# output filename, this can be anywhere you want, but lets save it to the Desktop directory
# as the daily data
dir_out = '~/Desktop'
fn_out = '{}/uv_geostrophic_ccs.nc'.format(dir_out)

# %%
# construct year array
yrs_wnt = np.arange(yr_bgn, yr_end+1)
num_yrs_wnt = len(yrs_wnt)

# construct day array
days_wnt = np.arange(day_bgn, day_end+1)
num_days_wnt = len(days_wnt)

# %%
# save the CCS subset data into a list
u_data_list = list()
v_data_list = list()
time_list = list()

for i in range(num_yrs_wnt):
    for j in range(num_days_wnt):
        # construct directory that has year and day subdirectories
        dir_yr_day = '{}/{}/{:03d}'.format(dir_in, yrs_wnt[i], days_wnt[j])

        # list the netcdf files in this directory
        fn_check = '{}/*.nc'.format(dir_yr_day)
        fn_nc = glob.glob(fn_check)

        # check to see if one file is in the directory
        num_fn_nc = len(fn_nc)
        
        if num_fn_nc == 1:
            # print the file name
            print(fn_nc[0])
            
            # open netcdf file using Xarray package (similar to Pandas but for geophysical data)
            ds1 = xr.open_dataset(fn_nc[0])

            # from the dataset create u and v DataArrays
            da_u = ds1[var_wnt[0]]
            da_v = ds1[var_wnt[1]]

            # subset u and v for CCS
            # this is where we use xarray sel function to subset the
            # global data down to the CCS region
            da_u_ccs = da_u.sel(lon=slice(lon_bgn, lon_end)).sel(
                lat=slice(lat_bgn, lat_end))

            da_v_ccs = da_v.sel(lon=slice(lon_bgn, lon_end)).sel(
                lat=slice(lat_bgn, lat_end))

            # append u and v data into list
            u_data_list.append(np.squeeze(da_u_ccs.data))
            v_data_list.append(np.squeeze(da_v_ccs.data))

            # append time to list, save it as a datetime64[ns] variable this
            # is helpful for creating a output netcdf file
            time_list.append(da_u_ccs.time.data.astype('datetime64[ns]'))
# Out:
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/001/20150101000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/002/20150102000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/003/20150103000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/004/20150104000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/005/20150105000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/006/20150106000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/007/20150107000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/008/20150108000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/009/20150109000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/010/20150110000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/011/20150111000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/012/20150112000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/013/20150113000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/014/20150114000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/015/20150115000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/016/20150116000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/017/20150117000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/018/20150118000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/019/20150119000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/020/20150120000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/021/20150121000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/022/20150122000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/023/20150123000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/024/20150124000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/025/20150125000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/026/20150126000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/027/20150127000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/028/20150128000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/029/20150129000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/030/20150130000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/031/20150131000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/032/20150201000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/033/20150202000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/034/20150203000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/035/20150204000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/036/20150205000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/037/20150206000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/038/20150207000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/039/20150208000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015/040/20150209000000-GLOBCURRENT-L4-CURgeo_0m-ALT_OI-v03.0-fv01.0.nc
# /Volumes/Saraf_EXT/GlobCurrent_geostrophic/geostrophic/2015
da1_u = xr.DataArray(u_ccs, coords=[time_vec, lat_ccs, lon_ccs],
                     dims=['time', 'lat', 'lon'])
da1_v = xr.DataArray(v_ccs, coords=[time_vec, lat_ccs, lon_ccs],
                     dims=['time', 'lat', 'lon'])

# create xarray dataset from the u and v DataArrays
ds1_out = da1_u.to_dataset(name='u')
ds1_out['v'] = da1_v

# can write attributes to the netcdf file similar to the original netcdf
ds1_out.attrs['geospatial_lat_min'] = np.min(lat_ccs)
ds1_out.attrs['geospatial_lat_max'] = np.max(lat_ccs)
ds1_out.attrs['geospatial_lon_min'] = np.min(lon_ccs)
ds1_out.attrs['geospatial_lon_max'] = np.max(lon_ccs)

# %%
# write this dataset to a netcdf file
ds1_out.to_netcdf(fn_out)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     197             try:
# --> 198                 file = self._cache[self._key]
#     199             except KeyError:
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/Users/esaraf/Desktop/uv_geostrophic_ccs.nc',), 'a', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# <ipython-input-26-3d5b1b40e08f> in <module>
#       1 # write this dataset to a netcdf file
# ----> 2 ds1_out.to_netcdf(fn_out)
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1552             unlimited_dims=unlimited_dims,
#    1553             compute=compute,
# -> 1554             invalid_netcdf=invalid_netcdf,
#    1555         )
#    1556
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1069                 "unrecognized option 'invalid_netcdf' for engine %s" % engine
#    1070             )
# -> 1071     store = store_open(target, mode, format, group, **kwargs)
#    1072
#    1073     if unlimited_dims is None:
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     356             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     357         )
# --> 358         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     359
#     360     def _acquire(self, needs_lock=True):
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     312         self._group = group
#     313         self._mode = mode
# --> 314         self.format = self.ds.data_model
#     315         self._filename = self.ds.filepath()
#     316         self.is_remote = is_remote_uri(self._filename)
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     365     @property
#     366     def ds(self):
# --> 367         return self._acquire()
#     368
#     369     def open_store_variable(self, name, var):
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     359
#     360     def _acquire(self, needs_lock=True):
# --> 361         with self._manager.acquire_context(needs_lock) as root:
#     362             ds = _nc4_require_group(root, self._group, self._mode)
#     363         return ds
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     184     def acquire_context(self, needs_lock=True):
#     185         """Context manager for acquiring a file."""
# --> 186         file, cached = self._acquire_with_cache_info(needs_lock)
#     187         try:
#     188             yield file
#
# ~/opt/miniconda3/envs/py3_parcels/lib/python3.6/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     202                     kwargs = kwargs.copy()
#     203                     kwargs["mode"] = self._mode
# --> 204                 file = self._opener(*self._args, **kwargs)
#     205                 if self._mode == "w":
#     206                     # ensure file doesn't get overriden when opened again
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# PermissionError: [Errno 13] Permission denied: b'/Users/esaraf/Desktop/uv_geostrophic_ccs.nc'
